# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pathlib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# Connecting to Drive
import google
google.colab.drive.mount('/content/drive', force_remount=True)
Main_dir="drive/MyDrive/NASA_Turbofan/"
# Out:
# Mounted at /content/drive

# %%
# Get Train and Test
df_train=pd.read_csv(Main_dir+"Master_train.csv")
df_test=pd.read_csv(Main_dir+"Master_test.csv")

list_to_drop=['Unnamed: 0','Engine_ID','Cycle',]
df_train.drop(list_to_drop, axis=1,inplace=True)
df_test.drop(list_to_drop, axis=1,inplace=True)

# %%
display(df_train)
# Out:
#             op1     op2    op3  sensor1  sensor2  sensor3  sensor4  sensor5  \
# 0       35.0001  0.8406  100.0   449.44   555.07  1366.16  1124.98     5.48
# 1       34.9986  0.8414  100.0   449.44   556.00  1366.52  1129.62     5.48
# 2        0.0003  0.0002  100.0   518.67   641.90  1581.77  1402.19    14.62
# 3       41.9989  0.8413  100.0   445.00   549.52  1352.72  1129.14     3.91
# 4       -0.0011  0.0003  100.0   518.67   643.00  1595.74  1406.22    14.62
# ...         ...     ...    ...      ...      ...      ...      ...      ...
# 128282  42.0079  0.8400  100.0   445.00   549.89  1352.87  1122.11     3.91
# 128283   0.0001  0.0006  100.0   518.67   642.80  1600.82  1412.14    14.62
# 128284  41.9984  0.8400  100.0   445.00   549.47  1357.41  1121.23     3.91
# 128285  10.0027  0.2500  100.0   489.05   604.66  1499.29  1303.47    10.52
# 128286   0.0008  0.0000  100.0   518.67   642.49  1589.73  1401.65    14.62
#
# ...

# %%
display(df_test)
# Out:
#            op1     op2    op3  sensor1  sensor2  sensor3  sensor4  sensor5  \
# 0      25.0061  0.6203   60.0   462.54   536.98  1262.09  1050.94     7.05
# 1       0.0006 -0.0004  100.0   518.67   642.52  1596.85  1407.11    14.62
# 2       9.9981  0.2515  100.0   489.05   604.82  1498.32  1311.02    10.52
# 3      -0.0024  0.0003  100.0   518.67   642.48  1587.00  1409.25    14.62
# 4      41.9986  0.8400  100.0   445.00   550.30  1359.90  1126.98     3.91
# ...        ...     ...    ...      ...      ...      ...      ...      ...
# 32067  10.0016  0.2519  100.0   489.05   604.73  1500.86  1300.22    10.52
# 32068   0.0001  0.0003  100.0   518.67   643.04  1601.88  1413.80    14.62
# 32069  20.0023  0.7002  100.0   491.19   607.62  1494.26  1254.59     9.35
# 32070  20.0001  0.7000  100.0   491.19   608.01  1482.61  1251.95     9.35
# 32071  25.0031  0.6200   60.0   462.54   536.92  1258.92  1058.17     7.05
#
# ...

# %% [markdown]
# ### Binary Classification

# %%
drop_list=['RUL','Sub_Status']
df_train.drop(drop_list, axis=1,inplace=True)
df_test.drop(drop_list, axis=1,inplace=True)

# %%
X_train=df_train.drop(['Status'], axis=1)
y_train=df_train['Status']
X_test=df_test.drop(['Status'], axis=1)
y_test=df_test['Status']

# %%
# Random Forest
forest = RandomForestClassifier(random_state=3)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=3)

# %%
y_pred_test = forest.predict(X_test)

# %%
y_pred_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
accuracy_score(y_test, y_pred_test)
# Out:
# 0.9839111998004489

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[ 1147,   271],
#        [  245, 30409]])

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82      1418
#            1       0.99      0.99      0.99     30654
#
#     accuracy                           0.98     32072
#    macro avg       0.91      0.90      0.90     32072
# weighted avg       0.98      0.98      0.98     32072

# %% [markdown]
# ### MultiClass Classification

# %%
drop_list=['RUL','Status']
df_train.drop(drop_list, axis=1,inplace=True)
df_test.drop(drop_list, axis=1,inplace=True)

# %%
X_train=df_train.drop(['Sub_Status'], axis=1)
y_train=df_train['Sub_Status']
X_test=df_test.drop(['Sub_Status'], axis=1)
y_test=df_test['Sub_Status']

# %%
# Random Forest
forest = RandomForestClassifier(random_state=3)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=3)

# %%
y_pred_test = forest.predict(X_test)

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#     Critical       0.82      0.81      0.81      1418
#      Warning       0.71      0.68      0.70      2836
#      Working       0.98      0.98      0.98     27818
#
#     accuracy                           0.95     32072
#    macro avg       0.84      0.82      0.83     32072
# weighted avg       0.95      0.95      0.95     32072

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[ 1149,   268,     1],
#        [  233,  1924,   679],
#        [   21,   502, 27295]])

# %% [markdown]
# ## Regression

# %%
drop_list=['Sub_Status','Status']
df_train.drop(drop_list, axis=1,inplace=True)
df_test.drop(drop_list, axis=1,inplace=True)

# %%
X_train=df_train.drop(['RUL'], axis=1)
y_train=df_train['RUL']
X_test=df_test.drop(['RUL'], axis=1)
y_test=df_test['RUL']

# %%
# Random Forest
forest = RandomForestRegressor(random_state=3)
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=3)

# %%
y_pred_test = forest.predict(X_test)

# %%
MSE=mean_squared_error(y_test, y_pred_test)

# %%
RMSE=MSE**0.5
print(RMSE)
# Out:
# 50.360638479935496
